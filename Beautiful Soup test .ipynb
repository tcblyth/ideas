# %%
# Install all python libraries required for this course.
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f5/2c/5edf2488897cad4fb8c4ace86369833552615bf264460ae4ef6e1f258982/scikit-learn-0.19.1.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/bf/2d/005e45738ab07a26e621c9c12dc97381f372e06678adf7dc3356a69b5960/numpy-1.13.3.zip
# ...
#      |████████████████████████████████| 14.4MB 17.6MB/s eta 0:00:01
# ...
#     ERROR: Complete output from command python setup.py egg_info:
#     ERROR: Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/dg/y06vk7ts6mg_lm85md6nhf4nnzr0vf/T/pip-install-ur7g9gjd/beautifulsoup/setup.py", line 22
#         print "Unit tests have failed!"
#                                       ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Unit tests have failed!")?
#     ----------------------------------------
# ...

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# ...
#   Stored in directory: /Users/blytht01/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# ...

# %%
# !pip install beautifulsoup4

# %%
import requests 
URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <title>Sky Sports Football \xe2\x80\x93 Telegram</title>\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" />\n    <meta name="format-detection" content="telephone=no" />\n    <meta http-equiv="X-UA-Compatible"\n     content="IE=edge" />\n    <meta name="MobileOptimized" content="176" />\n    <meta name="HandheldFriendly" content="True" />\n    \n<meta property="og:title" content="Sky Sports Football">\n<meta property="og:image" content="https://cdn4.telesco.pe/file/jZxfKGuTZAUu5AvZeggqgfLdNRGVeX6UZNAWZ1cML5sI9MimIjJIlTpjRPRQdEoIWyczVzCjFAkTzr79oBFeBAo1DtbyDNYqZFS4v9-sOuv1E598aRKNzEdwQYu_ghPO5MSvx66Oa0L-C6Nvavtpdf3kM2XdK5iKrON3twXkMxPQ3eyPKzMvD7GXtduh-l5jWjFuWGOdQNQvnWWfnk5niUXewVK3RUVFRbcPtAOGErbvwPZRkILseA4TqVIT5BLS3n7Bb18JlO2atwNSm88z2gxY41i4XoigTYmBkbtYe8MtJhPMphe54m_9UYHmkud7D84mnIaJ-izsXp7WYWVJww.jpg">\n<meta property="og:site_nam
# ...

# %%
#This will not run on online IDE 
import requests 
from bs4 import BeautifulSoup 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Sky Sports Football – Telegram
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="176" name="MobileOptimized"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="Sky Sports Football" property="og:title"/>
#   <meta content="https://cdn4.telesco.pe/file/emQxWt6QKsv8NDZDPUaAITYNnDdKjRR2uQuLNCcw4US27ZpBtDHnhRBFUtnFp2NIdPaBttbumkuVF9Xke-hmqFS_7V9NFNz19WPm53EFVjqKn-of0C8aJOheFN7JZQiYFRuVJHp2-mhQ5kkHPZAYDZOW8jX1srBX-_709PPfoij2VMXk1Wrv5v9aFNfvH6RWp2vRmtwJDE4_l3FjiSBrMgWpcZqBqdHhpDYtHkQAkVWeEdd5E7XI2fgGkvS2r6MuWV_M_x4G45mqOnvPxFNqCB9H3-f5L9D5FFUiiz7w4L_r_v0sgVWn7pI8hHd1lrQNW8Sf2h6xlJeP9L1wNNK7hA.jpg" property="og:image"/>
# ...

# %%
#This will not run on online IDE 
import requests 
from bs4 import BeautifulSoup 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Sky Sports Football – Telegram
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="176" name="MobileOptimized"/>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="Sky Sports Football" property="og:title"/>
#   <meta content="https://cdn4.telesco.pe/file/V_E45pdWhhBcUm4pEPG1gxpnHdkXF-AN3TzAXycVnK4NR57iRO_KTX6w8l9O9NR4qa8cPKnEMkcfGRxCXKh4UsPRMAhWLux7bIaiM-KJBS_ZKaMAS0y45hjm2P8yCLJCXGaSlolAEt_52HyFii5KpeLAUjUSDZJVkeCZS5H6LtBMxhq4iu3_XHsB4qZr9C-T0vGj_ojDrxA02HIR94xEkxy5fiup45pvzN-esycZvQ3iFmJ3BygPNoLQ0Wv1Wb3zacQrd4lhpcoLFZlGUUIjT4BbGf0ytINP1flM-BaWQPluW1kBwzHYvvo58SbFj2i53w1eMtTmcTBZA-WMI6WONw.jpg" property="og:image"/>
# ...

# %%
# !pip install tabulate
# Out:
# ...
#      |████████████████████████████████| 51kB 1.4MB/s eta 0:00:01
# ...
#   Stored in directory: /Users/blytht01/Library/Caches/pip/wheels/e1/41/5e/e201f95d90fc84f93aa629b6638adacda680fe63aac47174ab
# Successfully built tabulate
# ...

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 


tgme_channel_info_description=[] # a list to store quotes 

table = [soup.find('div', attrs = 'tgme_channel_info_description')] 

print(table)
# Out:
# [<div class="tgme_channel_info_description">Sky Sports Football is now on Telegram! Be the first one to read latest news, watch match highlights and follow exclusive content!<br/><br/>*Unofficial<br/><br/>Advertisment: <a href="https://t.me/cobbl" target="_blank">@cobbl</a><br/>Other questions: <a href="https://t.me/otchebuch" target="_blank">@otchebuch</a> <br/><br/><br/>Рекламная сеть - <a href="https://t.me/BelviorAd" target="_blank">@BelviorAd</a></div>]

# %%
import requests 
from bs4 import BeautifulSoup 
import csv 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 

text = [] # a list to store quotes 

table = soup.find('div', attrs = {"tgme_widget_message_text js-message_text"})

print(table)
# Out:
# <div class="tgme_widget_message_text js-message_text" dir="auto">We're just going to leave this here... thoughts? <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F9180.png')"><b>👀</b></i></div>

# %%
import requests 
from bs4 import BeautifulSoup 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
divTag = soup.find_all("div", {"class": "tgme_widget_message_text js-message_text"})

# %%
print(divTag)
# Out:
# [<div class="tgme_widget_message_text js-message_text" dir="auto">David De Gea left Spain’s European qualifier against Sweden with an injury. <br/><br/>Manchester United face Liverpool on Sunday <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F98B3.png')"><b>😳</b></i></div>, <div class="tgme_widget_message_text js-message_text" dir="auto">Our Manchester United Team of the Decade <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F94B4.png')"><b>🔴</b></i><br/><br/>Thoughts? <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09FA494.png')"><b>🤔</b></i></div>, <div class="tgme_widget_message_text js-message_text" dir="auto"><a href="?q=%23RedRivalry">#RedRivalry</a> <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F8DBF.png')"><b>🍿</b></i><br/><br/>Transport for Greater Manchester at it again with their road signs, ready for this Sunday... <i class="emoji" style="background-image:u
# ...

# %%
import requests 
from bs4 import BeautifulSoup 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 

divTag = soup.find_all("div", {"class": "tgme_widget_message_text js-message_text"})

print(divTag)
# Out:
# [<div class="tgme_widget_message_text js-message_text" dir="auto">Our Manchester United Team of the Decade <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F94B4.png')"><b>🔴</b></i><br/><br/>Thoughts? <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09FA494.png')"><b>🤔</b></i></div>, <div class="tgme_widget_message_text js-message_text" dir="auto"><a href="?q=%23RedRivalry">#RedRivalry</a> <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09F8DBF.png')"><b>🍿</b></i><br/><br/>Transport for Greater Manchester at it again with their road signs, ready for this Sunday... <i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/F09FA4A3.png')"><b>🤣</b></i></div>, <div class="tgme_widget_message_text js-message_text" dir="auto">These six teams have their tickets booked for EURO 2020: <br/><i class="emoji" style="background-image:url('//telegram.org/img/emoji/40/E29C85.png')"><b>✅</b></i> Italy<br
# ...

# %%
import requests 
from bs4 import BeautifulSoup 

URL = "https://t.me/s/sky_sports_football"
r = requests.get(URL) 

soup = BeautifulSoup(r.content, 'html5lib') 

divTag = soup.find_all("div", {"class": "tgme_widget_message_text js-message_text"})

print(divTag)
